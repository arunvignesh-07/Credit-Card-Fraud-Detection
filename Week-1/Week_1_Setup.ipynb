# %%
import pandas as pd
import numpy as np

# %%
print("Pandas version:", pd.__version__)
print("NumPy version:", np.__version__)
# Out:
# Pandas version: 2.2.3
# NumPy version: 2.1.3

# %%
data = np.array([10, 20, 30, 40, 50])

print("NumPy Array:")
print(data)

print("Mean:", np.mean(data))
print("Maximum:", np.max(data))
print("Minimum:", np.min(data))
# Out:
# NumPy Array:
# [10 20 30 40 50]
# Mean: 30.0
# Maximum: 50
# Minimum: 10

# %%
sample_data = {
    "Transaction_ID": [1, 2, 3, 4, 5],
    "Amount": [100, 250, 75, 500, 120],
    "Class": [0, 0, 1, 0, 1]
}

sample_df = pd.DataFrame(sample_data)

sample_df
# Out:
#    Transaction_ID  Amount  Class
# 0               1     100      0
# 1               2     250      0
# 2               3      75      1
# 3               4     500      0
# 4               5     120      1

# %%
print("Shape:", sample_df.shape)

print("\nColumns:")
print(sample_df.columns)

print("\nData Types:")
print(sample_df.dtypes)

print("\nSummary:")
print(sample_df.describe())
# Out:
# Shape: (5, 3)
#
# Columns:
# Index(['Transaction_ID', 'Amount', 'Class'], dtype='object')
#
# Data Types:
# Transaction_ID    int64
# Amount            int64
# Class             int64
# dtype: object
#
# Summary:
#        Transaction_ID      Amount     Class
# count        5.000000    5.000000  5.000000
# mean         3.000000  209.000000  0.400000
# std          1.581139  176.153342  0.547723
# min          1.000000   75.000000  0.000000
# 25%          2.000000  100.000000  0.000000
# 50%          3.000000  120.000000  0.000000
# 75%          4.000000  250.000000  1.000000
# max          5.000000  500.000000  1.000000
